# %%
import dotenv
import os
dotenv.load_dotenv()
import openai
from openai import AzureOpenAI

# %%
endpoint = "https://newazuredeployment.openai.azure.com/"
model_name = "o3-mini"
deployment = "o3-mini"
subscription_key = os.getenv("AZURE_OPENAI_KEY")
api_version = "2024-12-01-preview"

# %%
client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

# %%
response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        }
    ],
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# Paris is an amazing city with a mix of iconic landmarks, world-class museums, and charming neighborhoods. Here are some must-see attractions and experiences:
#
# • Eiffel Tower – No trip to Paris is complete without a visit to this landmark. Consider booking a ticket to go up for panoramic views or simply enjoy its sparkle at night from the Champ de Mars.
#
# • The Louvre – Home to masterpieces like the Mona Lisa and Venus de Milo, the Louvre is the world’s largest museum. Even if you can’t see it all, exploring a few key sections is a fantastic experience.
#
# • Musée d’Orsay – Housed in a converted railway station, this museum boasts incredible works of Impressionist art by Monet, Van Gogh, and others.
#
# • Notre-Dame Cathedral – Although the interior may still be under restoration, the exterior and its surroundings on the Île de la Cité are steeped in history.
#
# ...

# %%
prompt = "show me 5 receipes for a dish with the folowing ingredients: chicken, potatoes and carrots. Per recipe, list all the ingredients used"
messages = [{"role": "user", "content": prompt}]

# make completion
completion = openai.chat.completions.create(model=deployment_name, messages=messages)

# print response
for choice in completion.choices:
    print(choice.message.content)
# print(completion.choices[0].message.content)
# Out:
# Below are five different recipes that showcase chicken, potatoes, and carrots. Each recipe includes a complete list of ingredients so you can see what you’ll need.
#
# ─────────────────────────────
# 1. Roast Chicken with Potatoes and Carrots
#
# Ingredients:
# • 1 whole chicken (about 3–4 lbs) or 4 bone‐in chicken thighs
# • 4 medium potatoes, cut into wedges
# • 4 carrots, peeled and cut into 1-inch chunks
# • 4 cloves garlic, smashed
# • 2 tablespoons olive oil
# • 1 lemon (cut in half)
# • 2–3 sprigs fresh rosemary (or 1 teaspoon dried rosemary)
# • Salt and freshly ground black pepper
#
# Instructions (brief overview):
# • Preheat the oven to 400°F (200°C).
# • Place the chicken in a roasting pan; rub with olive oil, salt, and pepper. Stuff with lemon halves, garlic, and rosemary.
# • Toss the potato and carrot pieces in olive oil, salt, and pepper, and arrange around the chicken.
# ...

# %%
no_of_recipies=input("How many recipies do you want? ")

ingredients=input("list of ingredients: ")

filter = input("filter: e.g very spicy, vegetarian, etc. ")

prompt = f"show me {no_of_recipies} recipies for a dish with the following ingredients: {ingredients}. Per recipe, list all the ingredients used. no Filter: {filter}"

messages = [{"role": "user", "content": prompt}]

completion = client.chat.completions.create(model=deployment, messages=messages)


print("Recipies: ")

print(completion.choices[0].message.content)
# Out:
# Recipies:
# Here's one recipe that features chicken, rice, and broccoli with a spicy kick:
#
# Recipe: Spicy Chicken, Broccoli & Rice Stir-Fry
#
# Ingredients:
# • 1 lb chicken breast, cut into bite-sized pieces
# • 2 cups broccoli florets (about 1 medium head)
# • 1 cup uncooked rice (white or brown, your choice)
# • 2 tablespoons vegetable or olive oil
# • 3 garlic cloves, minced
# • 1 tablespoon fresh ginger, minced
# • ½ teaspoon red chili flakes (adjust for extra heat if desired)
# • 1 tablespoon chili garlic sauce (for added spice and depth)
# • 2 tablespoons soy sauce
# • Salt and pepper to taste
# • (Optional garnish: sliced green onions and sesame seeds)
#
# Directions:
# 1. Start by cooking the rice. Rinse 1 cup of rice under cold water, then add to a saucepan with 2 cups of water and a pinch of salt. Bring to a boil, reduce the heat to low, cover, and cook until tender and all water is absorbed (about 15 minutes for white rice or follow package directions for brown rice).
# ...

# %%
old_prompt_result = completion.choices[0].message.content
prompt_shopping = "Produce a shopping list, and please don't include ingredients that I already have at home: "

new_prompt = f"Given ingredients at home {ingredients} and these generated recipes: {old_prompt_result}, {prompt_shopping}"
messages = [{"role": "user", "content": new_prompt}]
completion = client.chat.completions.create(model=deployment, messages=messages)


print(completion.choices[0].message.content)
# Out:
# Shopping List:
# • Vegetable oil or olive oil
# • Garlic (at least 1 head or enough for 3 cloves)
# • Fresh ginger
# • Red chili flakes
# • Chili garlic sauce
# • Soy sauce
# • (Optional) Green onions
# • (Optional) Sesame seeds

# %%
# endpoint = "https://newazuredeployment.openai.azure.com/"
# model_name = "o3-mini"
# deployment = "o3-mini"
# api_key = os.getenv("AZURE_OPENAI_KEY")
# api_version = "2024-12-01-preview"

text_prompt = "Should oxford commas always be used?"

response = client.chat.completions.create(
model =deployment,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},])

response.choices[0].message.content
# Out:
# 'The Oxford comma, also known as the serial comma, isn’t a strict rule—its use largely depends on the style guide you follow and the need for clarity in your writing.\n\nMany style guides, like the Chicago Manual of Style and MLA, recommend its use to avoid ambiguity in lists. For example, in the sentence "I’d like to thank my parents, Ayn Rand and God," the absence of an Oxford comma might imply that Ayn Rand and God are your parents. Including the Oxford comma—"I’d like to thank my parents, Ayn Rand, and God"—eliminates that confusion.\n\nHowever, other style guides like the Associated Press (AP) style generally advise against using it unless omitting it would cause misunderstanding. This is why some publications and writers choose not to use it.\n\nIn summary, you should consider the context:\n• If you’re writing for a publication or institution, follow their style guidelines.\n• If clarity might be an issue, use the Oxford comma to avoid ambiguity.\n• If you’re following a style 
# ...

# %%
endpoint = "https://newazuredeployment.openai.azure.com/"
model_name = "o3-mini"
model = "o3-mini"
api_key = os.getenv("AZURE_OPENAI_KEY")
api_version = "2024-12-01-preview"

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
)   
print(response.choices[0].message.content)
# Out:
# Classified category: Hardware Support

# %%
prompt ="Product Description: A home milkshake maker \n seed words: fast. healthy, compact. \n product names: homeshaker, fitshaker, quickshake, shakermaker \n\n product description : a pair of shoes that can fit any shoe size. \n seed word: adaptable, fit, omni fit."

print(prompt)
# Out:
# Product Description: A home milkshake maker
#  seed words: fast. healthy, compact.
#  product names: homeshaker, fitshaker, quickshake, shakermaker
#
#  product description : a pair of shoes that can fit any shoe size.
#  seed word: adaptable, fit, omni fit.

# %%
response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ],
)   
print(response.choices[0].message.content)
# Out:
# Below are two distinct creative product descriptions that incorporate the provided seed words and product name ideas.
#
# ──────────────────────────────
# 1. Home Milkshake Maker
#
# Product Names: homeshaker, fitshaker, quickshake, shakermaker
#
# Description:
# Meet your new kitchen companion—a milkshake maker designed for those who demand speed, health, and space-saving style. Whether you call it homeshaker or quickshake, this compact appliance lets you whip up delicious, nutritious milkshakes in minutes. Its fast-acting motor means you get a smooth blend each time, while the emphasis on healthy, fresh ingredients makes it perfect for a balanced lifestyle. Ideal for busy mornings or a post-workout treat, this shaker maker fuses convenience with gourmet quality, all in a sleek, compact design that fits perfectly on any countertop.
#
# ──────────────────────────────
# 2. Shoes That Fit Every Foot
#
# Seed Words: adaptable, fit, omni fit
#
# Description:
# ...

# %%
# %pip install matplotlib plotly scikit-learn pandas
# Out:
# 8538.51s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 48.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 40.8 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 57.4 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 38.3 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.1/35.1 MB 49.9 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [matplotlib]7 [matplotlib]n]]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
model = 'text-embedding-ada-002'


text = 'the quick brown fox jumped over the lazy dog'
client.embeddings.create(input = [text], model=model).data[0].embedding
# Out:
# [-0.00457075284793973,
#  0.009826643392443657,
#  -0.01506032980978489,
#  -0.006350206211209297,
#  -0.011406265199184418,
#  0.015542463399469852,
#  -0.024157429113984108,
#  -0.015872344374656677,
#  -0.015999222174286842,
#  -0.029587775468826294,
#  0.021543757990002632,
#  0.02127731405198574,
#  0.01896814815700054,
#  0.004006149247288704,
#  -0.0007402494666166604,
#  -0.007644354365766048,
#  0.024893317371606827,
#  -0.004237700253725052,
#  0.011127134785056114,
#  -0.008576902560889721,
#  -0.008957534097135067,
#  0.02120118774473667,
#  -0.00641364511102438,
#  -0.00848808791488409,
#  0.006423160899430513,
#  0.013284048065543175,
#  0.007504789158701897,
#  -0.003229025984182954,
#  -0.00906537938863039,
#  0.0013853409327566624,
#  0.006591273006051779,
#  0.003971257712692022,
#  -0.039433449506759644,
#  -0.002605741610750556,
#  -0.012713100761175156,
#  -0.021670633926987648,
#  -0.0037270192988216877,
#  -0.010461029596626759,
#  0.026187464594841003,
# ...

# %%
import numpy as np

# %%
def cosine_similarity(a,b):
    return np.dot(a,b)/(np.linalg.norm(a) * np.linalg.norm(b))

# %%
# compare several words
automobile_embedding    = client.embeddings.create(input = 'automobile', model=model).data[0].embedding
vehicle_embedding       = client.embeddings.create(input = 'vehicle', model=model).data[0].embedding
dinosaur_embedding      = client.embeddings.create(input = 'dinosaur', model=model).data[0].embedding
stick_embedding         = client.embeddings.create(input = 'stick', model=model).data[0].embedding

# comparing cosine similarity, automobiles vs automobiles should be 1.0, i.e exactly the same, while automobiles vs dinosaurs should be between 0 and 1, i.e. not the same
print(cosine_similarity(automobile_embedding, automobile_embedding))
print(cosine_similarity(automobile_embedding, vehicle_embedding))
print(cosine_similarity(automobile_embedding, dinosaur_embedding))
print(cosine_similarity(automobile_embedding, stick_embedding))
# Out:
# 1.0
# 0.915739416418029
# 0.8329017718558467
# 0.7818148774886836
